# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
# load a clean dataset
def load_clean_sentences(filename):
    return load(open(filename, 'rb'))
 
# fit a tokenizer
def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer
 
# max sentence length
def max_length(lines):
    return max(len(line.split()) for line in lines)
 
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    X = tokenizer.texts_to_sequences(lines)
    # pad sequences with 0 values
    X = pad_sequences(X, maxlen=length, padding='post')
    return X
 
# one hot encode target sequence
def encode_output(sequences, vocab_size):
    ylist = list()
    for sequence in sequences:
        encoded = to_categorical(sequence, num_classes=vocab_size)
        ylist.append(encoded)
    y = array(ylist)
    y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
    return y
 
# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
    model = Sequential()
    model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
    model.add(LSTM(n_units))
    model.add(RepeatVector(tar_timesteps))
    model.add(LSTM(n_units, return_sequences=True))
    model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
    return model

# %%
# load datasets

dataset = load_clean_sentences('../data/mini_english-portuguese-training-both.pkl')
train = load_clean_sentences('../data/mini_english-portuguese-training.pkl')
validation = load_clean_sentences('../data/mini_english-portuguese-validation.pkl')

# %%
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare porutguese tokenizer
por_tokenizer = create_tokenizer(dataset[:, 1])
por_vocab_size = len(por_tokenizer.word_index) + 1
por_length = max_length(dataset[:, 1])
print('Portuguese Vocabulary Size: %d' % por_vocab_size)
print('Portuguese Max Length: %d' % (por_length))
 
# prepare training data
trainX = encode_sequences(por_tokenizer, por_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
validationX = encode_sequences(por_tokenizer, por_length, validation[:, 1])
validationY = encode_sequences(eng_tokenizer, eng_length, validation[:, 0])
validationY = encode_output(validationY, eng_vocab_size)
 
# define model
model = define_model(por_vocab_size, eng_vocab_size, por_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

fit1 = model.fit(trainX, trainY, epochs=30, batch_size=64, validation_data=(validationX, validationY), callbacks=callbacks_list, verbose=2)
# Out:
# English Vocabulary Size: 1269
# English Max Length: 5
# Portuguese Vocabulary Size: 2268
# Portuguese Max Length: 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 8, 256)            580608
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_3 (RepeatVecto (None, 5, 256)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 5, 1269)           326133
# =================================================================
# Total params: 1,957,365
# Trainable params: 1,957,365
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 4501 samples, validate on 500 samples
# Epoch 1/30
#  - 11s - loss: 4.3584 - val_loss: 3.3443
#
# Epoch 00001: val_loss improved from inf to 3.34431, saving model to model.h5
# Epoch 2/30
#  - 9s - loss: 3.0594 - val_loss: 2.9967
#
# Epoch 00002: val_loss improved from 3.34431 to 2.99672, saving model to model.h5
# Epoch 3/30
#  - 9s - loss: 2.8480 - val_loss: 2.9245
#
# Epoch 00003: val_loss improved from 2.99672 to 2.92448, saving model to model.h5
# Epoch 4/30
#  - 9s - loss: 2.7439 - val_loss: 2.8481
#
# Epoch 00004: val_loss improved from 2.92448 to 2.84809, saving model to model.h5
# Epoch 5/30
#  - 9s - loss: 2.6689 - val_loss: 2.8157
#
# Epoch 00005: val_loss improved from 2.84809 to 2.81565, saving model to model.h5
# Epoch 6/30
#  - 10s - loss: 2.6071 - val_loss: 2.7848
#
# Epoch 00006: val_loss improved from 2.81565 to 2.78480, saving model to model.h5
# Epoch 7/30
#  - 10s - loss: 2.5473 - val_loss: 2.7421
#
# Epoch 00007: val_loss improved from 2.78480 to 2.74206, saving model to model.h5
# Epoch 8/30
#  - 10s - loss: 2.4628 - val_loss: 2.7002
#
# Epoch 00008: val_loss improved from 2.74206 to 2.70016, saving model to model.h5
# Epoch 9/30
#  - 10s - loss: 2.3629 - val_loss: 2.6286
#
# Epoch 00009: val_loss improved from 2.70016 to 2.62858, saving model to model.h5
# Epoch 10/30
#  - 10s - loss: 2.2613 - val_loss: 2.5616
#
# Epoch 00010: val_loss improved from 2.62858 to 2.56158, saving model to model.h5
# Epoch 11/30
#  - 10s - loss: 2.1599 - val_loss: 2.4809
#
# Epoch 00011: val_loss improved from 2.56158 to 2.48088, saving model to model.h5
# Epoch 12/30
#  - 9s - loss: 2.0587 - val_loss: 2.4142
#
# Epoch 00012: val_loss improved from 2.48088 to 2.41416, saving model to model.h5
# Epoch 13/30
#  - 9s - loss: 1.9587 - val_loss: 2.3506
#
# Epoch 00013: val_loss improved from 2.41416 to 2.35057, saving model to model.h5
# Epoch 14/30
#  - 10s - loss: 1.8648 - val_loss: 2.3000
#
# Epoch 00014: val_loss improved from 2.35057 to 2.30000, saving model to model.h5
# Epoch 15/30
#  - 9s - loss: 1.7792 - val_loss: 2.2501
#
# Epoch 00015: val_loss improved from 2.30000 to 2.25013, saving model to model.h5
# Epoch 16/30
#  - 9s - loss: 1.6945 - val_loss: 2.2080
#
# Epoch 00016: val_loss improved from 2.25013 to 2.20801, saving model to model.h5
# Epoch 17/30
#  - 9s - loss: 1.6090 - val_loss: 2.1808
#
# Epoch 00017: val_loss improved from 2.20801 to 2.18080, saving model to model.h5
# Epoch 18/30
#  - 10s - loss: 1.5289 - val_loss: 2.1279
#
# Epoch 00018: val_loss improved from 2.18080 to 2.12790, saving model to model.h5
# Epoch 19/30
#  - 10s - loss: 1.4576 - val_loss: 2.1125
#
# Epoch 00019: val_loss improved from 2.12790 to 2.11255, saving model to model.h5
# Epoch 20/30
#  - 10s - loss: 1.3866 - val_loss: 2.0750
#
# Epoch 00020: val_loss improved from 2.11255 to 2.07501, saving model to model.h5
# Epoch 21/30
#  - 11s - loss: 1.3147 - val_loss: 2.0508
#
# Epoch 00021: val_loss improved from 2.07501 to 2.05079, saving model to model.h5
# Epoch 22/30
#  - 10s - loss: 1.2521 - val_loss: 2.0422
#
# Epoch 00022: val_loss improved from 2.05079 to 2.04215, saving model to model.h5
# Epoch 23/30
#  - 10s - loss: 1.1824 - val_loss: 1.9978
#
# Epoch 00023: val_loss improved from 2.04215 to 1.99779, saving model to model.h5
# Epoch 24/30
#  - 9s - loss: 1.1155 - val_loss: 1.9835
#
# Epoch 00024: val_loss improved from 1.99779 to 1.98346, saving model to model.h5
# Epoch 25/30
#  - 9s - loss: 1.0562 - val_loss: 1.9510
#
# Epoch 00025: val_loss improved from 1.98346 to 1.95097, saving model to model.h5
# Epoch 26/30
#  - 9s - loss: 1.0026 - val_loss: 1.9512
#
# Epoch 00026: val_loss did not improve from 1.95097
# Epoch 27/30
#  - 10s - loss: 0.9442 - val_loss: 1.9232
#
# Epoch 00027: val_loss improved from 1.95097 to 1.92324, saving model to model.h5
# Epoch 28/30
#  - 10s - loss: 0.8901 - val_loss: 1.9103
#
# Epoch 00028: val_loss improved from 1.92324 to 1.91032, saving model to model.h5
# Epoch 29/30
#  - 10s - loss: 0.8326 - val_loss: 1.8876
#
# Epoch 00029: val_loss improved from 1.91032 to 1.88762, saving model to model.h5
# Epoch 30/30
#  - 10s - loss: 0.7812 - val_loss: 1.8841
#
# Epoch 00030: val_loss improved from 1.88762 to 1.88412, saving model to model.h5

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(fit1.history['loss'])
plt.plot(fit1.history['val_loss'])
plt.legend(['train','validation'])
plt.show()
